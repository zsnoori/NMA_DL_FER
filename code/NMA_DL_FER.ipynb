# %% [markdown]
# <a href="https://colab.research.google.com/github/alaeimo/NMA_DL_FER/blob/master/code/NMA_DL_FER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports
import os
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls
# Out:
# drive  sample_data

# %%
dataset_root = "./drive/MyDrive/Colab Notebooks/datasets/"

# %%
classes = {0:"Angry", 1:"Disgust", 2:"Fear", 3:"Happy", 4:"Sad", 5:"Surprise", 6:"Neutral"}
classes_inv = {"Angry":0, "Disgust":1, "Fear":2, "Happy":3, "Sad":4, "Surprise":5, "Neutral":6}

# %%
#Data loading
training_dataset = torchvision.datasets.FER2013(
     root=dataset_root, split='train')

test_dataset = torchvision.datasets.FER2013(
     root=dataset_root, split='test')

# %%
for i in range(20):
  ax = plt.subplot(4,5, i+1)
  img, label = training_dataset._samples[i]
  ax.imshow(img, cmap="gray")
  ax.set_title(classes[label])
  ax.set_axis_off()
plt.tight_layout()

# %%
#Preprocessing

# %%
#Model

# %%
# List pretrained models in TorchVision
# classification_models = list_models(module=torchvision.models)
